# %%
ls
# Out:
# Just_a_peek.ipynb  listings.csv  raw/  reviews.csv

# %%
import pandas as pd

# %%
raw_lists = pd.read_csv("raw/listings.csv")

# %%
print(raw_lists.columns)

for col_name in raw_lists.columns:
    print("\n \n ----",col_name)
    print(raw_lists[col_name].unique())
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
raw_lists.shape
# Out:
# (11922, 96)

# %%
raw_lists.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1   5570   https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
# 2   8095   https://www.airbnb.com/rooms/8095  20181115100559   2018-11-15
# 3  39516  https://www.airbnb.com/rooms/39516  20181115100559   2018-11-15
# 4  45429  https://www.airbnb.com/rooms/45429  20181115100559   2018-11-15
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                 Art Studio Retreat/Rustic Cabin
# 4                 OB cottage SD--view on waterway
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
reviews =  pd.read_csv("raw/reviews.csv")

# %%
print(reviews.columns)

for col_name in reviews.columns:
    print("\n \n ----",col_name)
    print(reviews[col_name].unique())
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')
#
#
#  ---- listing_id
# [       6     8095    39516 ... 29899812 29927527 29980961]
#
#
#  ---- id
# [        8      4383   1722383 ... 347734002 347998489 348607383]
#
#
#  ---- date
# ['2008-06-22' '2009-06-22' '2012-07-16' ... '2018-11-15' '2018-11-18'
#  '2018-11-17']
#
#
#  ---- reviewer_id
# [      415      3762   1864778 ... 114232678 204688051   9929686]
#
#
#  ---- reviewer_name
# ['Terrence' 'Christine' 'Hieu' ... 'Shigeko' 'Jinsol' 'Sri Raj Dutt']
#
#
#  ---- comments
# ['Sara is an awesome hostess.  She was very considerate, making me feel right at home.  Her suggestions of local well-known and up-and-coming hotspots were also very helpful.  Definitely a positive experience.  Her dog is a sweetie too!'
# ...

# %%
reviews.shape
# Out:
# (344404, 6)

# %%
calendar =  pd.read_csv("calendar.csv")

# %%
print(calendar.columns)

for col_name in calendar.columns:
    print("\n \n ----",col_name)
    print(calendar[col_name].unique())
# Out:
# Index(['listing_id', 'date', 'available', 'price'], dtype='object')
#
#
#  ---- listing_id
# [  635756   292285   293133 ... 29957907 29958570 29960453]
#
#
#  ---- date
# ['2019-11-14' '2019-11-13' '2019-11-12' '2019-11-11' '2019-11-10'
#  '2019-11-09' '2019-11-08' '2019-11-07' '2019-11-06' '2019-11-05'
#  '2019-11-04' '2019-11-03' '2019-11-02' '2019-11-01' '2019-10-31'
#  '2019-10-30' '2019-10-29' '2019-10-28' '2019-10-27' '2019-10-26'
#  '2019-10-25' '2019-10-24' '2019-10-23' '2019-10-22' '2019-10-21'
#  '2019-10-20' '2019-10-19' '2019-10-18' '2019-10-17' '2019-10-16'
#  '2019-10-15' '2019-10-14' '2019-10-13' '2019-10-12' '2019-10-11'
#  '2019-10-10' '2019-10-09' '2019-10-08' '2019-10-07' '2019-10-06'
#  '2019-10-05' '2019-10-04' '2019-10-03' '2019-10-02' '2019-10-01'
#  '2019-09-30' '2019-09-29' '2019-09-28' '2019-09-27' '2019-09-26'
#  '2019-09-25' '2019-09-24' '2019-09-23' '2019-09-22' '2019-09-21'
#  '2019-09-20' '2019-07-25' '2019-07-24' '2019-07-23' '2019-07-22'
# ...

# %%
lists = pd.read_csv("listings.csv")

# %%
print(lists.columns)

for col_name in lists.columns:
    print("\n \n ----",col_name)
    print(lists[col_name].unique())
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')
#
#
#  ---- id
# [       6     5570     8095 ... 30048505 30048809 30049974]
#
#
#  ---- name
# ['Large Craftsmen w/ yard ~ Perfect for families'
#  'Ocean front condo on the sand' 'Sunset Cliffs Studio' ...
#  'Clean\nBright and Simple' 'Cozy pillow top air mattress' 'Cozy bedroom']
#
#
#  ---- host_id
# [      29     8435      270 ... 28969185 96115938 97914402]
#
#
#  ---- host_name
# ['Sara' "Jef Karchin'S MISSIONBEACHRETREAT" 'Marin' ... 'Shadiya And Eli'
#  'Dakota' 'Wanda']
#
#
#  ---- neighbourhood_group
# [nan]
#
#
#  ---- neighbourhood
# ['North Hills' 'Mission Bay' 'Ocean Beach' 'Loma Portal' 'La Jolla'
# ...
